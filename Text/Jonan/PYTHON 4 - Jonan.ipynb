# %%
str1 = input("Input a word: ")
str2 = input("Input a second word: ")
str3 = " "
n1 = 0
for ch in str1:
    str3 += (str1[n1] + str2[n1])
    n1+= 1
print (str3)

# %%
check = input("Input a sentence to see if it's a palindrome: ")
cleaner = ''.join(filter(str.isalnum, check))
print (cleaner)
n1 = 0
n2 = -1
reverse = ""
for ch in cleaner:
    reverse += (cleaner[n2]); n2-= 1
if reverse == cleaner:
    print("This is a palindrome.")
else:
    print("This is not a palindrome")

# %%
str1 = input(" Input your string: ")
isbeghilos = True
n = -1
reversebeg = ""
mapping = {'b': '8', 'e': '3', 'g': '6', 'h': '4','i': '1', 'l': '7', 'o': '0', 's': '5', 'B': '8', 'E': '3', 'G': '6', 'H': '4','I': '1', 'L': '7', 'O': '0', 'S': '5'}
def convertbeg(text):
    result = "".join(mapping.get(char, char) for char in text)
    return result
for char in str1:
    if char not in mapping:
        isbeghilos = False
        print(f"String contains non-beghilos characters.")
        break
if isbeghilos == True:
    converted = convertbeg(str1)
    for int in converted:
        reversebeg += (converted[n])
        n -= 1
    print(f"Original: {str1}")
    print(f"Beghilos: {reversebeg}")
