# %%
str1 = input("Give me a word: ")
str2 = str1.replace(" ", "")
str2 = ''.join(filter(str.isalnum, str2))
rev = ""
count = 0
for ch in str2:
    rev = str2[count] + rev
    count += 1

if rev.lower() == str2.lower():
    print(str1 + " is a palindrome")
else:
    print(str1 + " is not a palindrome")
