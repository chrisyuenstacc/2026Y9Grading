# %%
word1 = input("Give me a word: ");
word2 = input("Give me a word of the same length: ");
final = "";
count = 0;
for i in word1:
    final += word1[count] + word2[count]; count += 1;
print(final);
