# %%
L1 = [1,2,3]
L2 = [4,5,6]
L1.append(L2)
print(L1)
# Out:
# [1, 2, 3, [4, 5, 6]]

# %%
GuestList =  []

def AddGuest(Guest):
    GuestList.append(GuestName)
    print(GuestName + " added to list")

def RemoveGuest(Guest):
    if GuestName in GuestList:
        GuestList.remove(GuestName)
        print(GuestName + " removed from list")
    else:
        print(GuestName + " not found")

def AskName():
    GuestName = input("Name of guest: ")
    return GuestName


while True:
    Selection = int(input("1: Add Guest | 2: Remove Guest | 3: Print Guest List | -1: Quit: "))
    if Selection == 1: 
       GuestName = AskName()
       AddGuest(GuestName)

    elif Selection == 2:
        GuestName = AskName()
        RemoveGuest(GuestName)

    elif Selection == 3:
        print(GuestList)

    elif Selection == -1:
        break

    else:
        print(str(Selection + " is an invalid choice"))

for i in GuestList:
    print(i + " will attend")
print(str(len(GuestList)) + " people will come")
# Out:
# Ben added to list
# Jonan added to list
# Steve added to list
# ['Ben', 'Jonan', 'Steve']
# Ben will attend
# Jonan will attend
# Steve will attend
# 3 people will come
